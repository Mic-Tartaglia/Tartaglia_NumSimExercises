# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory </span>
# ## <span style="color:brown"> Python Exercise 11 </span>
# ## <span style="color:orange"> Keras - Neural Network regression </span>

# %% [markdown]
# ### Overview
#
# In this notebook our task will be to perform machine learning regression on noisy data with a Neural Network (NN).
#
# We will explore how the ability to fit depends on the structure of the NN. The goal is also to build intuition about why prediction is difficult.

# %% [markdown]
# ### The Prediction Problem
#
# Consider a probabilistic process that gives rise to labeled data $(x,y)$. The data is generated by drawing samples from the equation
#
# $$
#     y_i= f(x_i) + \eta_i,
# $$
#
# where $f(x_i)$ is some fixed, but (possibly unknown) function, and $\eta_i$ is a Gaussian, uncorrelate noise variable such that
#
# $$
# \langle \eta_i \rangle=0 \\
# \langle \eta_i \eta_j \rangle = \delta_{ij} \sigma
# $$
#
# We will refer to the $f(x_i)$ as the **true features** used to generate the data.
#
# To make prediction, we will consider a NN that depend on its parameters, weights and biases. The functions that the NN can model respresent the **model class** that we are using to try to model the data and make predictions.
#
# To learn the parameters of the NN, we will train our models on a **training data set** and then test the effectiveness of the NN on a *different* dataset, the **validation data set**. The reason we must divide our data into a training and test dataset is that the point of machine learning is to make accurate predictions about new data we have not seen.
#
# To measure our ability to predict, we will learn our parameters by fitting our training dataset and then making predictions on our test data set. One common measure of predictive  performance of our algorithm is to compare the predictions,$\{y_j^\mathrm{pred}\}$, to the true values $\{y_j\}$. A commonly employed measure for this is the sum of the mean square-error (MSE) on the test set:
# $$
# MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2
# $$
#
# We will try to get a qualitative picture by examining plots on validation and training data.

# %% [markdown]
# ### Linear fit
#
# We start by considering the very simple case:
# $$
# f(x)=2x+1
# $$

# %% [markdown]
# Let's start defining the parameters of an ideal linear function which we are going to predict through a neural network regression

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# %% [markdown]
# Now let's generate a set of input data which will slightly deviate from our ideal behaviour using a random noise (that actually is set to zero):

# %%
import numpy as np

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 1000)
x_valid = np.random.uniform(-1, 1, 100)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 1. # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# %%
# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %% [markdown]
# If you remember how a single node of a neural network works, you can easily spot that **just a single neuron can make the job**. So let's start using a simple Sequential model with just one layer on one neuron only!

# %%
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
from tensorflow.keras.optimizers import Adam

model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])

# %%
# get a summary of our composed model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We are now going to train our model, that is we feed the neuron with the set of training pair x, y_train from which the optimizer will find the best weights to minimize the Mean Square Error loss function (out linear regression function).

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9482 - mse: 0.9482 - val_loss: 0.8205 - val_mse: 0.8205
# Epoch 2/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9483 - mse: 0.9483 - val_loss: 0.8215 - val_mse: 0.8215
# Epoch 3/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9482 - mse: 0.9482 - val_loss: 0.8208 - val_mse: 0.8208
# Epoch 4/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9486 - mse: 0.9486 - val_loss: 0.8202 - val_mse: 0.8202
# Epoch 5/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9483 - mse: 0.9483 - val_loss: 0.8210 - val_mse: 0.8210
# Epoch 6/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9486 - mse: 0.9486 - val_loss: 0.8210 - val_mse: 0.8210
# Epoch 7/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9482 - mse: 0.9482 - val_loss: 0.8219 - val_mse: 0.8219
# Epoch 8/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9485 - mse: 0.9485 - val_loss: 0.8220 - val_mse: 0.8220
# Epoch 9/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9482 - mse: 0.9482 - val_loss: 0.8206 - val_mse: 0.8206
# Epoch 10/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9483 - mse: 0.9483 - val_loss: 0.8208 - val_mse: 0.8208
# Epoch 11/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9486 - mse: 0.9486 - val_loss: 0.8205 - val_mse: 0.8205
# Epoch 12/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9482 - mse: 0.9482 - val_loss: 0.8206 - val_mse: 0.8206
# Epoch 13/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9487 - mse: 0.9487 - val_loss: 0.8202 - val_mse: 0.8202
# Epoch 14/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9483 - mse: 0.9483 - val_loss: 0.8199 - val_mse: 0.8199
# Epoch 15/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9485 - mse: 0.9485 - val_loss: 0.8203 - val_mse: 0.8203
# Epoch 16/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9483 - mse: 0.9483 - val_loss: 0.8202 - val_mse: 0.8202
# Epoch 17/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9482 - mse: 0.9482 - val_loss: 0.8199 - val_mse: 0.8199
# Epoch 18/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9484 - mse: 0.9484 - val_loss: 0.8195 - val_mse: 0.8195
# Epoch 19/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9483 - mse: 0.9483 - val_loss: 0.8203 - val_mse: 0.8203
# Epoch 20/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9486 - mse: 0.9486 - val_loss: 0.8208 - val_mse: 0.8208
# Epoch 21/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9483 - mse: 0.9483 - val_loss: 0.8211 - val_mse: 0.8211
# Epoch 22/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9485 - mse: 0.9485 - val_loss: 0.8210 - val_mse: 0.8210
# Epoch 23/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9481 - mse: 0.9481 - val_loss: 0.8209 - val_mse: 0.8209
# Epoch 24/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9482 - mse: 0.9482 - val_loss: 0.8207 - val_mse: 0.8207
# Epoch 25/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9482 - mse: 0.9482 - val_loss: 0.8204 - val_mse: 0.8204
# Epoch 26/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9482 - mse: 0.9482 - val_loss: 0.8205 - val_mse: 0.8205
# Epoch 27/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9483 - mse: 0.9483 - val_loss: 0.8200 - val_mse: 0.8200
# Epoch 28/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9482 - mse: 0.9482 - val_loss: 0.8197 - val_mse: 0.8197
# Epoch 29/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9484 - mse: 0.9484 - val_loss: 0.8199 - val_mse: 0.8199
# Epoch 30/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9485 - mse: 0.9485 - val_loss: 0.8202 - val_mse: 0.8202

# %%
# return weights
model.get_weights()
# Out:
# [array([[2.002893]], dtype=float32), array([1.0208266], dtype=float32)]

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8215 - mse: 0.8215
#
# Test loss: 0.8215280771255493
# Test accuracy: 0.8215280771255493

# %%
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 4.3229e-04 - mse: 4.3229e-04
#
# Test loss: 0.0004322866734582931
# Test accuracy: 0.0004322866734582931

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-1, 3, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_predicted, m*x_predicted+b)
plt.plot(np.ones(4),np.linspace(-1,7,4),color = 'green')
plt.grid(True)
plt.legend(['Exact','Limit of "Training Zone"','Predicted'])
plt.show()

# %% [markdown]
# ### Exercise 11.1
#
# In order to make practice with NN, explore how does the previous linear regression depend on the number of epochs, $N_{\mathrm{epochs}}$, the number of data points $N_{\mathrm{train}}$ and on the noise $\sigma$. Try to improve the previous result operating on these parameters.

# %% [markdown]
# **With the linear model it quite easy to get accurate results. I found the most important parameter to be the number of train points. Even with modest noise (of order $\approx$ 1) the predictions are accurate if the number of train points is $\gtrapprox 10^3$, and they converge in about 20 Epochs.**

# %% [markdown]
# ### Exercise 11.2
#
# Try to extend the model to obtain a reasonable fit of the following polynomial of order 3:
#
# $$
# f(x)=4-3x-2x^2+3x^3
# $$
# for $x \in [-1,1]$.
#
# In order to make practice with NN, explore reasonable different choices for:
#
# - the number of layers
# - the number of neurons in each layer
# - the activation function
# - the optimizer
# - the loss function
#
# Make graphs comparing fits for different NNs.
# Check your NN models by seeing how well your fits predict newly generated test data (including on data outside the range you fit. How well do your NN do on points in the range of $x$ where you trained the model? How about points outside the original training data set?
# Summarize what you have learned about the relationship between model complexity (number of parameters), goodness of fit on training data, and the ability to predict well.

# %%
def pol_3(x):
  return 4 - 3*x -2*x**2 + 3*x**3

# %%
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 10000)
x_valid = np.random.uniform(-1, 1, 1000)
x_valid.sort()
y_target = pol_3(x_valid) # ideal (target) cubic function

sigma = 0.15 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(pol_3(x_train), sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(pol_3(x_valid), sigma)

# %%
# plot training and target dataset
import matplotlib.pyplot as plt
plt.plot(x_valid, y_target)
plt.scatter(x_valid, y_valid, color='r')
plt.grid(True); plt.show()

# %%
model2 = tf.keras.Sequential()

model2.add(Dense(20, input_shape=(1,),activation='elu'))
model2.add(Dense(100, input_shape=(1,),activation='elu'))
model2.add(Dense(100, input_shape=(1,),activation='elu'))
#model2.add(Dense(4, input_shape=(1,),activation='elu'))
model2.add(Dense(1, input_shape=(1,),activation = 'elu'))

# compile the model choosing optimizer, loss and metrics objects
sgd = keras.optimizers.SGD(learning_rate=0.01)
model2.compile(optimizer=sgd, loss='mse', metrics=['mse'])

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 20)                40
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               2100
# _________________________________________________________________
# dense_3 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 12,341
# Trainable params: 12,341
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data
history2 = model2.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/30
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5694 - mse: 0.5694 - val_loss: 0.3133 - val_mse: 0.3133
# Epoch 2/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2218 - mse: 0.2218 - val_loss: 0.1832 - val_mse: 0.1832
# Epoch 3/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1291 - mse: 0.1291 - val_loss: 0.0981 - val_mse: 0.0981
# Epoch 4/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0855 - mse: 0.0855 - val_loss: 0.0769 - val_mse: 0.0769
# Epoch 5/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0623 - mse: 0.0623 - val_loss: 0.0554 - val_mse: 0.0554
# Epoch 6/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0478 - val_mse: 0.0478
# Epoch 7/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0431 - mse: 0.0431 - val_loss: 0.0421 - val_mse: 0.0421
# Epoch 8/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0408 - mse: 0.0408 - val_loss: 0.0401 - val_mse: 0.0401
# Epoch 9/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0390 - mse: 0.0390 - val_loss: 0.0372 - val_mse: 0.0372
# Epoch 10/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0377 - mse: 0.0377 - val_loss: 0.0400 - val_mse: 0.0400
# Epoch 11/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0368 - mse: 0.0368 - val_loss: 0.0365 - val_mse: 0.0365
# Epoch 12/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0360 - mse: 0.0360 - val_loss: 0.0347 - val_mse: 0.0347
# Epoch 13/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0352 - mse: 0.0352 - val_loss: 0.0407 - val_mse: 0.0407
# Epoch 14/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0347 - mse: 0.0347 - val_loss: 0.0334 - val_mse: 0.0334
# Epoch 15/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0340 - mse: 0.0340 - val_loss: 0.0351 - val_mse: 0.0351
# Epoch 16/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0333 - mse: 0.0333 - val_loss: 0.0327 - val_mse: 0.0327
# Epoch 17/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0329 - mse: 0.0329 - val_loss: 0.0334 - val_mse: 0.0334
# Epoch 18/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0326 - mse: 0.0326 - val_loss: 0.0326 - val_mse: 0.0326
# Epoch 19/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0320 - mse: 0.0320 - val_loss: 0.0311 - val_mse: 0.0311
# Epoch 20/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0317 - mse: 0.0317 - val_loss: 0.0308 - val_mse: 0.0308
# Epoch 21/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0312 - mse: 0.0312 - val_loss: 0.0303 - val_mse: 0.0303
# Epoch 22/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0309 - mse: 0.0309 - val_loss: 0.0322 - val_mse: 0.0322
# Epoch 23/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0304 - mse: 0.0304 - val_loss: 0.0293 - val_mse: 0.0293
# Epoch 24/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0298 - mse: 0.0298 - val_loss: 0.0397 - val_mse: 0.0397
# Epoch 25/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0297 - mse: 0.0297 - val_loss: 0.0293 - val_mse: 0.0293
# Epoch 26/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0295 - mse: 0.0295 - val_loss: 0.0292 - val_mse: 0.0292
# Epoch 27/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0288 - mse: 0.0288 - val_loss: 0.0294 - val_mse: 0.0294
# Epoch 28/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0287 - mse: 0.0287 - val_loss: 0.0286 - val_mse: 0.0286
# Epoch 29/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0283 - mse: 0.0283 - val_loss: 0.0273 - val_mse: 0.0273
# Epoch 30/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0281 - mse: 0.0281 - val_loss: 0.0311 - val_mse: 0.0311

# %%
 # evaluate model
score = model2.evaluate(x_valid, y_valid, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0311 - mse: 0.0311
#
# Test loss: 0.031086795032024384
# Test accuracy: 0.031086795032024384

# %%
# evaluate model with the exact curve
score = model2.evaluate(x_valid, y_target, batch_size=32, verbose=1)

# print performance
print()
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0100 - mse: 0.0100
#
# Test loss: 0.00999081414192915
# Test accuracy: 0.00999081414192915

# %%
# look into training history
# Plot training & validation loss values
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')
plt.show()

# %%
x_predicted = np.random.uniform(-2, 2, 300)
x_predicted.sort()
y_predicted = model2.predict(x_predicted)

plt.figure(figsize=(10,7))

plt.scatter(x_predicted, y_predicted,color='r')
plt.plot(x_predicted, pol_3(x_predicted))
plt.grid(True)
plt.legend(['Exact','Predicted'])
plt.title('10^4 train points - 3x20 dense layers - 20 epochs',fontsize = 18)

plt.plot(np.ones(10),np.linspace(-20,15,10),color = 'green')
plt.plot(-np.ones(10),np.linspace(-20,15,10),color = 'green')

plt.show()

# %% [markdown]
# **Again I found the most important parameter to determine a good fit was the number of train points. With $10^4$ points, even with a big number of layers or epoch the convergence was not very accurate, especially in the last "tail" of the graph. In every image below, $\sigma$ is set to 0.2**
# **<br>The above graph instead shows that, while inside the "training range" prediction are fairly accurate, outside of it they are wildly wrong**

# %%
from IPython.display import Image
Image('pic1.png',width = 500,height = 400)

# %%
Image('pic2.png',width = 500,height = 400)

# %%
Image('pic3.png',width = 500,height = 400)

# %% [markdown]
# **As can be seen above, even by reducing greatly the network complexity and the time at its disposal for training, the fit is really good with many training points**

# %% [markdown]
# ### Exercise 11.3
#
# Try to extend the model to fit a simple trigonometric 2D function such as $f(x,y) = \sin(x^2+y^2)$ in the range $x \in [-3/2,3/2]$ and $y \in [-3/2,3/2]$.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize = (10,7))
ax = fig.add_subplot(111, projection='3d')

X = np.linspace(-1.5, 1.5, 100)
Y = np.linspace(-1.5, 1.5, 100)
X, Y = np.meshgrid(X, Y)
R2 = X**2 + Y**2
Z = np.sin(R2)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, color = 'orange')

ax.set_title("Exact function surface",fontsize = 20)
# Out:
# Text(0.5, 0.92, 'Exact function surface')

# %%
x_trial = np.random.uniform(low= -1.5, high = 1.5,size = (10000,2))
x_valid = np.random.uniform(low= -1.5, high = 1.5,size = (1000,2))
def R2(x,y):
    return x**2 + y**2
y_trial = np.asarray([np.sin(R2(point[0],point[1])) for point in x_trial])
y_valid = np.asarray([np.sin(R2(point[0],point[1])) for point in x_valid])

fig = plt.figure(figsize = (16,7))
ax = fig.add_subplot(121, projection='3d')
surf = ax.scatter(x_trial[:,0],x_trial[:,1], y_trial, color = 'orange')
ax.set_title('Trial points with no noise',fontsize = 18)

sigma = 0.2
y_trial = np.random.normal(y_trial,sigma)
y_valid = np.random.normal(y_valid,sigma)

ax2 = fig.add_subplot(122, projection='3d')
surf2 = ax2.scatter(x_trial[:,0],x_trial[:,1], y_trial, color = 'orange')
ax2.set_title('Trial points with gaussian noise, sigma = '+str(sigma),fontsize = 18)

print(y_valid[0])

plt.show()
# Out:
# 0.4830522151073583

# %%
model3 = tf.keras.Sequential()

model3.add(Dense(50, input_shape=(2,),activation='elu'))
model3.add(Dense(50, input_shape=(1,),activation='elu'))
model3.add(Dense(50, input_shape=(1,2),activation='elu'))
#model3.add(Dense(10, input_shape=(1,2),activation='elu'))
model3.add(Dense(1, input_shape=(1,),activation = 'elu'))

# compile the model choosing optimizer, loss and metrics objects
sgd = keras.optimizers.SGD(learning_rate=0.01)
model3.compile(optimizer=sgd, loss='mse', metrics=['mse'])

# %%
model3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 50)                150
# _________________________________________________________________
# dense_14 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_15 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 51
# =================================================================
# Total params: 5,301
# Trainable params: 5,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit the model using training dataset
# over 10 epochs of 32 batch size each
# report training progress against validation data

print(x_valid.shape)

history3 = model3.fit(x=x_trial, y=y_trial, 
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# (1000, 2)
# Epoch 1/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0606 - mse: 0.0606 - val_loss: 0.0539 - val_mse: 0.0539
# Epoch 2/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0587 - mse: 0.0587 - val_loss: 0.0587 - val_mse: 0.0587
# Epoch 3/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0577 - mse: 0.0577 - val_loss: 0.1001 - val_mse: 0.1001
# Epoch 4/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0561 - mse: 0.0561 - val_loss: 0.0578 - val_mse: 0.0578
# Epoch 5/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0546 - mse: 0.0546 - val_loss: 0.0521 - val_mse: 0.0521
# Epoch 6/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0533 - mse: 0.0533 - val_loss: 0.0543 - val_mse: 0.0543
# Epoch 7/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0532 - mse: 0.0532 - val_loss: 0.0509 - val_mse: 0.0509
# Epoch 8/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0520 - mse: 0.0520 - val_loss: 0.0533 - val_mse: 0.0533
# Epoch 9/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0512 - mse: 0.0512 - val_loss: 0.0500 - val_mse: 0.0500
# Epoch 10/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0505 - mse: 0.0505 - val_loss: 0.0470 - val_mse: 0.0470
# Epoch 11/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0467 - val_mse: 0.0467
# Epoch 12/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0617 - val_mse: 0.0617
# Epoch 13/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0537 - val_mse: 0.0537
# Epoch 14/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0482 - mse: 0.0482 - val_loss: 0.0470 - val_mse: 0.0470
# Epoch 15/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0483 - mse: 0.0483 - val_loss: 0.0476 - val_mse: 0.0476
# Epoch 16/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0473 - mse: 0.0473 - val_loss: 0.0468 - val_mse: 0.0468
# Epoch 17/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0477 - mse: 0.0477 - val_loss: 0.0628 - val_mse: 0.0628
# Epoch 18/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0474 - mse: 0.0474 - val_loss: 0.0455 - val_mse: 0.0455
# Epoch 19/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0466 - mse: 0.0466 - val_loss: 0.0466 - val_mse: 0.0466
# Epoch 20/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0472 - mse: 0.0472 - val_loss: 0.0475 - val_mse: 0.0475
# Epoch 21/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0462 - mse: 0.0462 - val_loss: 0.0477 - val_mse: 0.0477
# Epoch 22/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0461 - mse: 0.0461 - val_loss: 0.0468 - val_mse: 0.0468
# Epoch 23/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0458 - mse: 0.0458 - val_loss: 0.0446 - val_mse: 0.0446
# Epoch 24/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0465 - mse: 0.0465 - val_loss: 0.0448 - val_mse: 0.0448
# Epoch 25/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0461 - mse: 0.0461 - val_loss: 0.0724 - val_mse: 0.0724
# Epoch 26/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0463 - mse: 0.0463 - val_loss: 0.0447 - val_mse: 0.0447
# Epoch 27/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0456 - mse: 0.0456 - val_loss: 0.0612 - val_mse: 0.0612
# Epoch 28/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0454 - mse: 0.0454 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 29/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0444 - mse: 0.0444 - val_loss: 0.0485 - val_mse: 0.0485
# Epoch 30/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0452 - mse: 0.0452 - val_loss: 0.0451 - val_mse: 0.0451
# Epoch 31/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0446 - mse: 0.0446 - val_loss: 0.0420 - val_mse: 0.0420
# Epoch 32/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0447 - mse: 0.0447 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 33/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0443 - mse: 0.0443 - val_loss: 0.0464 - val_mse: 0.0464
# Epoch 34/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0446 - mse: 0.0446 - val_loss: 0.0464 - val_mse: 0.0464
# Epoch 35/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0450 - mse: 0.0450 - val_loss: 0.0429 - val_mse: 0.0429
# Epoch 36/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0444 - mse: 0.0444 - val_loss: 0.0529 - val_mse: 0.0529
# Epoch 37/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0443 - mse: 0.0443 - val_loss: 0.0427 - val_mse: 0.0427
# Epoch 38/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0442 - mse: 0.0442 - val_loss: 0.0624 - val_mse: 0.0624
# Epoch 39/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0442 - mse: 0.0442 - val_loss: 0.0613 - val_mse: 0.0613
# Epoch 40/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0437 - mse: 0.0437 - val_loss: 0.0588 - val_mse: 0.0588
# Epoch 41/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0439 - mse: 0.0439 - val_loss: 0.0423 - val_mse: 0.0423
# Epoch 42/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0438 - mse: 0.0438 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 43/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0508 - val_mse: 0.0508
# Epoch 44/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0440 - mse: 0.0440 - val_loss: 0.0469 - val_mse: 0.0469
# Epoch 45/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0441 - mse: 0.0441 - val_loss: 0.0457 - val_mse: 0.0457
# Epoch 46/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0434 - mse: 0.0434 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 47/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0500 - val_mse: 0.0500
# Epoch 48/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0435 - mse: 0.0435 - val_loss: 0.0431 - val_mse: 0.0431
# Epoch 49/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0430 - val_mse: 0.0430
# Epoch 50/50
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0432 - mse: 0.0432 - val_loss: 0.0474 - val_mse: 0.0474

# %% [markdown]
# Ideas to meditate on these exercises and judge your results can be found <a href=https://xkcd.com/2048/>here</a>

# %%
x_predicted = np.random.uniform(-3, 3, size=(1000,2))
y_predicted = model3.predict(x_predicted)
y_exact = np.asarray([np.sin(R2(point[0],point[1])) for point in x_predicted])

plt.figure(figsize=(15,10))

fig = plt.figure(figsize = (16,7))
ax = fig.add_subplot(121, projection='3d')
surf = ax.scatter(x_predicted[:,0],x_predicted[:,1], y_predicted, color = 'red')
ax.scatter(x_predicted[:,0],x_predicted[:,1], y_exact, color = 'blue')

ax.legend(['Predicted','Exact'])
ax.set_title('10^4 training points - 3x50 dense layers - 150 epochs',fontsize = 15)

plt.show()

# %% [markdown]
# **Again, it is fairly easy to co**

# %% [markdown]
# ### <span style="color:green">Supplementary material: Keras model.fit available callbacks</span>

# %% [markdown]
# The .fit method can also get <a href=https://keras.io/callbacks/>callback</a> functions which can be used to customize the fitting procedure with special actions.
#
# Keras provides some predefined callbacks to feed in, among them for example:
# - **TerminateOnNaN()**: that terminates training when a NaN loss is encountered
# - **ModelCheckpoint(filepath)**: that save the model after every epoch
# - **EarlyStopping()**: which stop training when a monitored quantity has stopped improving
#
# You can select one or more callback and pass them as a list to the callback argument of the fit method.

# %% [markdown]
# Now we are going to construct a callback object to represent how estimated parameters are converging during the training procedure

# %%
from IPython.display import clear_output

class PlotCurrentEstimate(tf.keras.callbacks.Callback):
    def __init__(self, x_valid, y_valid):
        """Keras Callback which plot current model estimate against reference target"""
        
        # convert numpy arrays into lists for plotting purposes
        self.x_valid = list(x_valid[:])
        self.y_valid = list(y_valid[:])
        self.iter=0

    def on_epoch_end(self, epoch, logs={}):
        
        temp = self.model.predict(self.x_valid, batch_size=None, verbose=False, steps=None)
        self.y_curr = list(temp[:]) # convert numpy array into list
        
        self.iter+=1
        if self.iter%10 == 0:
            clear_output(wait=True)            
            self.eplot = plt.subplot(1,1,1)
            self.eplot.clear()     
            self.eplot.scatter(self.x_valid, self.y_curr, color="blue", s=4, marker="o", label="estimate")
            self.eplot.scatter(self.x_valid, self.y_valid, color="red", s=4, marker="x", label="valid")
            self.eplot.legend()

            plt.show()

# %% [markdown]
# We will use also an EarlyStopping callback on the val_loss quantity. This will stop the training process as soon as the val_loss quantity does not improve anymore after an amount of epochs, preventing a long time of wated computation to take over without useful results.
#
# <code>keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=False)</code>
#
# Arguments:
#
# - <code>monitor</code>: quantity to be monitored.
# - <code>min_delta:</code> minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
# - <code>patience:</code> number of epochs with no improvement after which training will be stopped.
# - <code>verbose:</code> verbosity mode.
# - <code>mode:</code> one of {auto, min, max}. In min mode, training will stop when the quantity monitored has stopped decreasing; in max mode it will stop when the quantity monitored has stopped increasing; in auto mode, the direction is automatically inferred from the name of the monitored quantity.
# - <code>baseline:</code> Baseline value for the monitored quantity to reach. Training will stop if the model doesn't show improvement over the baseline.
# - <code>restore_best_weights:</code> whether to restore model weights from the epoch with the best value of the monitored quantity. If False, the model weights obtained at the last step of training are used.

# %%
plot_estimate = PlotCurrentEstimate(x_valid, y_valid)

earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                  min_delta=0, patience=100, mode='auto')

model.fit(x_valid, y_valid, batch_size=32, epochs=150,
          validation_data=(x_valid, y_valid),
          callbacks=[ plot_estimate, earlystop]
          )

model.get_weights()
# Out:
# 10/10 [==============================] - 0s 21ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# [array([[1.7890505]], dtype=float32), array([1.0447811], dtype=float32)]
