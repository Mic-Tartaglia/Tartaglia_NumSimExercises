# %% [markdown]
# ### Exercise 02.1
# - Compute the following 1D integral via Monte Carlo
# $$I = \int_0^1 \frac{\pi}{2}\cos(\pi x/2) dx = 1$$
# 1. sampling a uniform distribution in $[0,1]$
# 2. using importance sampling (i.e. sampling a non-uniform probability in $[0,1]$)
#
# <span style="color:red">Show a picture of both your estimations of $I$</span> and their uncertainties with a large number of *throws* $M$ (e.g. $M\ge 10^4$) as a function of the number of blocks, $N$</font>.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
integrals = np.loadtxt("es2_1/results.dat")
err = np.loadtxt("es2_1/errors.dat")

M=1e4
N=1e2
L = int(M/N)

x = L* np.arange(N)

plt.figure(figsize=(15,6))
plt.errorbar(x,integrals - 1,yerr=err)
plt.xlabel("# of throws")
plt.ylabel(" I - 1")
plt.grid(True)
plt.show()

# %%
integrals = np.loadtxt("es2_102/results.dat")
err = np.loadtxt("es2_102/errors.dat")

M=1e4
N=1e2
L = int(M/N)

x = L* np.arange(N)

plt.figure(figsize=(15,6))
plt.errorbar(x,integrals - 1,yerr=err)
plt.xlabel("# of throws")
plt.ylabel(" I - 1")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 02.2
# - <span style="color:red">3D Random Walks (RW) on a cubic lattice and in the continuum:</span> Repeat many times (e.g. say $10^4$) the simulation of a random walk in 3D always starting at the origin
# 1. on a cubic lattice with lattice constant $a=1$; at each discrete time the walker makes a forward or backward step of length equal to $a$ in one of the 3 principal directions of the lattice: $x$, $y$ or $z$
# 2. in the continuum; at each discrete time the walker makes a step of length equal to $a(=1)$ along a **random direction** obtained by sampling **uniformly** the solid angle: $\theta \in [0,\pi]$ and $\phi \in [0,2\pi]$
#
# <span style="color:red">Show a picture of $\sqrt{\langle |\vec{r}_N|^2 \rangle_{RW}}$ for both RWs</span>, with their statistical uncertainties, as function of the step $i\in [0,10^2]$.
#
# Note that you could try to fit both results with a function like $f(N)=k\sqrt{N}$. Do your results indicate a diffusive behavior?

# %%
dist = np.loadtxt('es2_2/results.dat')
err = np.loadtxt('es2_2/errors.dat')

dist = np.insert(dist, 0, 0)
err = np.insert(err,0,0)

N=dist.size
x = np.arange(N)

plt.figure(figsize=(15,9))
plt.errorbar(x,dist,yerr=err)
plt.xlabel("# of steps")
plt.ylabel("Average distance")
plt.grid(True)
plt.show()

# %%
dist2 = dist**2

fit = np.polyfit(x,dist2,1)

plt.figure(figsize=(15,9))
plt.errorbar(x,dist2,yerr=err)
plt.xlabel("# of steps")
plt.ylabel("Square of average distance")
plt.grid(True)
plt.show()

k = np.sqrt(fit[0])

print(k)
# Out:
# 0.92468106571313

# %%
dist = np.loadtxt('es2_202/results.dat')
err = np.loadtxt('es2_202/errors.dat')

dist = np.insert(dist, 0, 0)
err = np.insert(err,0,0)

#print(dist.size)

N=dist.size
x = np.arange(N)

plt.figure(figsize=(15,9))
plt.errorbar(x,dist, yerr=err)
#plt.xlabel("# of steps")
plt.ylabel("Average distance")
plt.grid(True)
plt.show()

# %%
# squaring the distance

dist2 = dist**2

fit = np.polyfit(x,dist2,1)

plt.figure(figsize=(15,9))
plt.errorbar(x,dist2,yerr=err)
plt.xlabel("# of steps")
plt.ylabel("Average distance")
plt.grid(True)
plt.show()

k = np.sqrt(fit[0])

print(k)
# Out:
# 0.9197964011752988

# %%
#check = np.loadtxt("es2_202/check.out")
#plt.hist(check, bins=100)
#plt.show()

# %%
#read data into arrays

#data=list(np.zeros(N))
#errors=list(np.zeros(N))
#N=100
#
#with open('es2_2/results.dat', 'r') as file:
#    for i in range(N):
#        data[i]=[]
#        for number in file.readline().split(' '):
#            if number != '\n' and number!=' ':
#                data[i].append((number))    
#        data[i]=[float(elem) for elem in data[i]]
#        data[i]=np.array(data[i])
#        
#with open('es2_2/errors.dat', 'r') as file:
#    for i in range(N):
#        errors[i]=[]
#        for number in file.readline().split(' '):
#            if number != '\n' and number!=' ':
#                data[i].append((number))    
#        data[i]=[float(elem) for elem in data[i]]
#        data[i]=np.array(data[i])
